# %%
#Importing the libraries
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import keras
import tensorflow as tf
from tensorflow.python.data import Dataset
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers.core import Dense,Activation
from keras.layers import Input, Dropout
import pandas as pd
import numpy as np

# %%
#Loading the breastcancer dataset from csv file
dataset= pd.read_csv("/content/Breast Cancer.csv")
print(dataset)
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
#Using iloc() to select rows and columns
#x=dataset[dataset.columns[2:32]]
x=dataset.iloc[:, 2:32].values
y=dataset.iloc[:, 1].values
le = LabelEncoder()
# Fit label encoder and return encoded labels M=1, B=0
y = le.fit_transform(y)

#Splitting data into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y , train_size = 0.7, random_state =  90)

# %%
np.random.seed(100)
#Creation and implementation of model
model=Sequential()

#Performing on hidden layer
model.add(Dense(20, input_dim=30, activation='relu'))
model.add(Dense(25, input_dim=30, activation='relu'))
model.add(Dense(30, input_dim=30, activation='relu'))

#On output layer
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(x_train, y_train, epochs=100, verbose=0, initial_epoch=0)

# %%
#Printing the accuracy result before normalization
print(model.summary())
print(model.evaluate(D1_test, D2_test))
# Out:
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_134 (Dense)            (None, 20)                620
# _________________________________________________________________
# dense_135 (Dense)            (None, 25)                525
# _________________________________________________________________
# dense_136 (Dense)            (None, 30)                780
# _________________________________________________________________
# dense_137 (Dense)            (None, 1)                 31
# ...
# Total params: 1,956
# Trainable params: 1,956
# Non-trainable params: 0
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5116 - accuracy: 0.7203
# [0.5116083025932312, 0.7202796936035156]

# %%
#Performing Feature Extraction
D1=dataset.iloc[:, 2:32].values
D2=dataset.iloc[:, 1].values

#Printing the values
print(dataset.iloc[:, 1].value_counts())
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#Encoding the categorical Data
le= LabelEncoder()

#Returning encoded labels M=1, B=0
D2=le.fit_transform(D2)

# %%
#Implementing Standardization
sc=StandardScaler()
D1_Scaled = sc.fit_transform(D1)
D1_train, D1_test, D2_train, D2_test = train_test_split(D1_Scaled, D2, test_size=0.25, random_state=0)

# %%
#Creation and implementation of model
model=Sequential()

#Performing on hidden layer
model.add(Dense(20, input_dim=30, activation='relu'))
model.add(Dense(25, input_dim=30, activation='relu'))
model.add(Dense(30, input_dim=30, activation='relu'))

#On output layer
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(D1_train, D2_train,validation_data=(D1_test, D2_test), epochs=100, verbose=0, initial_epoch=0)

# %%
#Printing the accuracy after normalization
print(model.summary())
print(model.evaluate(D1_test, D2_test))
# Out:
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_138 (Dense)            (None, 20)                620
# _________________________________________________________________
# dense_139 (Dense)            (None, 25)                525
# _________________________________________________________________
# dense_140 (Dense)            (None, 30)                780
# _________________________________________________________________
# dense_141 (Dense)            (None, 1)                 31
# ...
# Total params: 1,956
# Trainable params: 1,956
# Non-trainable params: 0
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2512 - accuracy: 0.9510
# [0.25118735432624817, 0.9510489702224731]
